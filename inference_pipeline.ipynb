# %%
# Add logic to save transformed data to repo
# Clean up

from time import gmtime, strftime

import boto3
import sagemaker
import joblib
import pandas as pd
from sagemaker.sklearn.estimator import SKLearn
from sagemaker.model import Model
from sagemaker.pipeline import PipelineModel
from sagemaker.image_uris import retrieve

# %% [markdown]
# X_train, X_val, ..., y_train, y_val, ... need to have no headers

# %% [markdown]
# # Train featurizer on local

# %%
! python3 featurizer.py --raw-schema-path "schema.yml" --target-col "rings" --X-train-path "data/split/" --X-train-file "X_train.csv" --model-dir ./

# %% [markdown]
# # Train featurizer on separate instance

# %%
sm_boto3 = boto3.client('sagemaker')
sess = sagemaker.Session()
region = sess.boto_session.region_name
role = sagemaker.get_execution_role()
bucket = "kyle-abalone"

# %%
bucket

# %%
raw_schema_path = sess.upload_data(
    path='schema.yml', 
    bucket=bucket,
    key_prefix='abalone'
)
X_train_path = sess.upload_data(
    path='data/split/X_train.csv', 
    bucket=bucket,
    key_prefix='abalone/data/split'
)
y_train_path = sess.upload_data(
    path='data/split/y_train.csv', 
    bucket=bucket,
    key_prefix='abalone/data/split'
)
X_test_path = sess.upload_data(
    path='data/split/X_test.csv', 
    bucket=bucket,
    key_prefix='abalone/data/split'
)
y_test_path = sess.upload_data(
    path='data/split/y_test.csv', 
    bucket=bucket,
    key_prefix='abalone/data/split'
)

# %%
FRAMEWORK_VERSION = "0.23-1"
script_path = "featurizer.py"

featurizer = SKLearn(
    entry_point=script_path,
    role=role,
    framework_version=FRAMEWORK_VERSION,
    instance_type="ml.c4.xlarge",
    sagemaker_session=sess,
    source_dir='./'
)

# %%
featurizer.fit({'train': X_train_path, 'raw_schema_path': raw_schema_path}, wait=True, logs=True)
# Out:
# 2021-06-24 22:03:48 Starting - Starting the training job...
# 2021-06-24 22:04:12 Starting - Launching requested ML instancesProfilerReport-1624572227: InProgress
# .........
# 2021-06-24 22:05:33 Starting - Preparing the instances for training.........
# 2021-06-24 22:07:13 Downloading - Downloading input data
# 2021-06-24 22:07:13 Training - Downloading the training image...
# 2021-06-24 22:07:43 Uploading - Uploading generated training model2021-06-24 22:07:38,819 sagemaker-containers INFO     Imported framework sagemaker_sklearn_container.training
# 2021-06-24 22:07:38,822 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-06-24 22:07:38,832 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 2021-06-24 22:07:39,301 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# /miniconda3/bin/python -m pip install -r requirements.txt
# Collecting pyyaml==5.4.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
# Installing collected packages: pyyaml
# Successfully installed pyyaml-5.4.1
# 2021-06-24 22:07:40,944 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-06-24 22:07:40,957 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-06-24 22:07:40,969 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-06-24 22:07:40,980 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "raw_schema_path": "/opt/ml/input/data/raw_schema_path",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_sklearn_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {},
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "raw_schema_path": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "sagemaker-scikit-learn-2021-06-24-22-03-47-691",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-926521026587/sagemaker-scikit-learn-2021-06-24-22-03-47-691/source/sourcedir.tar.gz",
#     "module_name": "featurizer",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "featurizer.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={}
# SM_USER_ENTRY_POINT=featurizer.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"raw_schema_path":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["raw_schema_path","train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=featurizer
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_sklearn_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-926521026587/sagemaker-scikit-learn-2021-06-24-22-03-47-691/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"raw_schema_path":"/opt/ml/input/data/raw_schema_path","train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{},"input_config_dir":"/opt/ml/input/config","input_data_config":{"raw_schema_path":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"sagemaker-scikit-learn-2021-06-24-22-03-47-691","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-926521026587/sagemaker-scikit-learn-2021-06-24-22-03-47-691/source/sourcedir.tar.gz","module_name":"featurizer","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"featurizer.py"}
# SM_USER_ARGS=[]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_RAW_SCHEMA_PATH=/opt/ml/input/data/raw_schema_path
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# PYTHONPATH=/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python37.zip:/miniconda3/lib/python3.7:/miniconda3/lib/python3.7/lib-dynload:/miniconda3/lib/python3.7/site-packages
#
# Invoking script with the following command:
#
# /miniconda3/bin/python featurizer.py
#
#
# 2021-06-24 22:07:43,008 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2021-06-24 22:08:13 Completed - Training job completed
# ProfilerReport-1624572227: NoIssuesFound
# Training seconds: 58
# Billable seconds: 58

# %% [markdown]
# # Build batch transformer to transform X_train and X_test using featurizer

# %%
featurizer = joblib.load('model.joblib')

# %%
X_train = pd.read_csv('data/split/X_train.csv')
#loaded_model.transform()

# %%
X_train.head()

# %%
artifact = sm_boto3.describe_training_job(
    TrainingJobName=featurizer.latest_training_job.name)

# %%
artifact

# %%
transformer = featurizer.transformer(
    instance_count=1, instance_type="ml.m5.xlarge", assemble_with="Line", accept="text/csv"
)

# %%
transformer.transform(X_train_path, content_type="text/csv")
transformer.wait()
transformed_X_train = transformer.output_path

transformer.transform(X_test_path, content_type="text/csv")
transformer.wait()
transformed_X_test = transformer.output_path
# Out:
# ................................2021-06-24 22:13:44,761 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2021-06-24 22:13:44,763 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2021-06-24 22:13:44,761 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2021-06-24 22:13:44,763 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2021-06-24 22:13:44,764 INFO - sagemaker-containers - nginx config:
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr;
#
# worker_rlimit_nofile 4096;
#
# events {
#   worker_connections 2048;
# }
#
# http {
#   include /etc/nginx/mime.types;
#   default_type application/octet-stream;
#   access_log /dev/stdout combined;
#
#   upstream gunicorn {
#     server unix:/tmp/gunicorn.sock;
#   }
#
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#
#     keepalive_timeout 3;
#
#     location ~ ^/(ping|invocations|execution-parameters) {
#       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#       proxy_set_header Host $http_host;
#       proxy_redirect off;
#       proxy_read_timeout 60s;
#       proxy_pass http://gunicorn;
#     }
#
#     location / {
#       return 404 "{}";
#     }
#
#   }
# }
#
#
# 2021-06-24 22:13:44,938 INFO - sagemaker-containers - Module featurizer does not provide a setup.py.
# Generating setup.py
# 2021-06-24 22:13:44,938 INFO - sagemaker-containers - Generating setup.cfg
# 2021-06-24 22:13:44,938 INFO - sagemaker-containers - Generating MANIFEST.in
# 2021-06-24 22:13:44,939 INFO - sagemaker-containers - Installing module with the following command:
# /miniconda3/bin/python -m pip install . -r requirements.txt
# Processing /opt/ml/code
# Collecting pyyaml==5.4.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
# Building wheels for collected packages: featurizer
#   Building wheel for featurizer (setup.py): started
#   Building wheel for featurizer (setup.py): finished with status 'done'
#   Created wheel for featurizer: filename=featurizer-1.0.0-py2.py3-none-any.whl size=394200 sha256=3d0d6e6256eba6f9253e92e7e1efe851909c552b8807a6afab1c6fe97789420b
#   Stored in directory: /home/model-server/tmp/pip-ephem-wheel-cache-1rjdfewg/wheels/3e/0f/51/2f1df833dd0412c1bc2f5ee56baac195b5be563353d111dca6
# Successfully built featurizer
# Installing collected packages: pyyaml, featurizer
# Successfully installed featurizer-1.0.0 pyyaml-5.4.1
# [2021-06-24 22:13:47 +0000] [36] [INFO] Starting gunicorn 20.0.4
# [2021-06-24 22:13:47 +0000] [36] [INFO] Listening at: unix:/tmp/gunicorn.sock (36)
# [2021-06-24 22:13:47 +0000] [36] [INFO] Using worker: gevent
# [2021-06-24 22:13:47 +0000] [39] [INFO] Booting worker with pid: 39
# [2021-06-24 22:13:47 +0000] [40] [INFO] Booting worker with pid: 40
# [2021-06-24 22:13:47 +0000] [44] [INFO] Booting worker with pid: 44
# [2021-06-24 22:13:47 +0000] [45] [INFO] Booting worker with pid: 45
# 2021-06-24 22:13:49,561 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2021-06-24 22:13:44,764 INFO - sagemaker-containers - nginx config:
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr;
#
# worker_rlimit_nofile 4096;
#
# events {
#   worker_connections 2048;
# }
#
# http {
#   include /etc/nginx/mime.types;
#   default_type application/octet-stream;
#   access_log /dev/stdout combined;
#
#   upstream gunicorn {
#     server unix:/tmp/gunicorn.sock;
#   }
#
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#
#     keepalive_timeout 3;
#
#     location ~ ^/(ping|invocations|execution-parameters) {
#       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#       proxy_set_header Host $http_host;
#       proxy_redirect off;
#       proxy_read_timeout 60s;
#       proxy_pass http://gunicorn;
#     }
#
#     location / {
#       return 404 "{}";
#     }
#
#   }
# }
#
#
# 2021-06-24 22:13:44,938 INFO - sagemaker-containers - Module featurizer does not provide a setup.py.
# Generating setup.py
# 2021-06-24 22:13:44,938 INFO - sagemaker-containers - Generating setup.cfg
# 2021-06-24 22:13:44,938 INFO - sagemaker-containers - Generating MANIFEST.in
# 2021-06-24 22:13:44,939 INFO - sagemaker-containers - Installing module with the following command:
# /miniconda3/bin/python -m pip install . -r requirements.txt
# Processing /opt/ml/code
# Collecting pyyaml==5.4.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
# Building wheels for collected packages: featurizer
#   Building wheel for featurizer (setup.py): started
#   Building wheel for featurizer (setup.py): finished with status 'done'
#   Created wheel for featurizer: filename=featurizer-1.0.0-py2.py3-none-any.whl size=394200 sha256=3d0d6e6256eba6f9253e92e7e1efe851909c552b8807a6afab1c6fe97789420b
#   Stored in directory: /home/model-server/tmp/pip-ephem-wheel-cache-1rjdfewg/wheels/3e/0f/51/2f1df833dd0412c1bc2f5ee56baac195b5be563353d111dca6
# Successfully built featurizer
# Installing collected packages: pyyaml, featurizer
# Successfully installed featurizer-1.0.0 pyyaml-5.4.1
# [2021-06-24 22:13:47 +0000] [36] [INFO] Starting gunicorn 20.0.4
# [2021-06-24 22:13:47 +0000] [36] [INFO] Listening at: unix:/tmp/gunicorn.sock (36)
# [2021-06-24 22:13:47 +0000] [36] [INFO] Using worker: gevent
# [2021-06-24 22:13:47 +0000] [39] [INFO] Booting worker with pid: 39
# [2021-06-24 22:13:47 +0000] [40] [INFO] Booting worker with pid: 40
# [2021-06-24 22:13:47 +0000] [44] [INFO] Booting worker with pid: 44
# [2021-06-24 22:13:47 +0000] [45] [INFO] Booting worker with pid: 45
# 2021-06-24 22:13:49,561 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [24/Jun/2021:22:13:50 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Jun/2021:22:13:50 +0000] "GET /execution-parameters HTTP/1.1" 404 232 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Jun/2021:22:13:50 +0000] "POST /invocations HTTP/1.1" 200 436211 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Jun/2021:22:13:50 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Jun/2021:22:13:50 +0000] "GET /execution-parameters HTTP/1.1" 404 232 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Jun/2021:22:13:50 +0000] "POST /invocations HTTP/1.1" 200 436211 "-" "Go-http-client/1.1"
# 2021-06-24T22:13:50.084:[sagemaker logs]: MaxConcurrentTransforms=1, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
#
# 2021-06-24 22:13:44,761 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2021-06-24 22:13:44,763 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2021-06-24 22:13:44,761 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2021-06-24 22:13:44,763 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2021-06-24 22:13:44,764 INFO - sagemaker-containers - nginx config:
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr;
#
# worker_rlimit_nofile 4096;
#
# events {
#   worker_connections 2048;
# }
#
# http {
#   include /etc/nginx/mime.types;
#   default_type application/octet-stream;
#   access_log /dev/stdout combined;
#
#   upstream gunicorn {
#     server unix:/tmp/gunicorn.sock;
#   }
#
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#
#     keepalive_timeout 3;
#
#     location ~ ^/(ping|invocations|execution-parameters) {
#       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#       proxy_set_header Host $http_host;
#       proxy_redirect off;
#       proxy_read_timeout 60s;
#       proxy_pass http://gunicorn;
#     }
#
#     location / {
#       return 404 "{}";
#     }
#
#   }
# }
#
#
# 2021-06-24 22:13:44,938 INFO - sagemaker-containers - Module featurizer does not provide a setup.py.
# Generating setup.py
# 2021-06-24 22:13:44,938 INFO - sagemaker-containers - Generating setup.cfg
# 2021-06-24 22:13:44,938 INFO - sagemaker-containers - Generating MANIFEST.in
# 2021-06-24 22:13:44,939 INFO - sagemaker-containers - Installing module with the following command:
# /miniconda3/bin/python -m pip install . -r requirements.txt
# Processing /opt/ml/code
# Collecting pyyaml==5.4.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
# Building wheels for collected packages: featurizer
#   Building wheel for featurizer (setup.py): started
#   Building wheel for featurizer (setup.py): finished with status 'done'
#   Created wheel for featurizer: filename=featurizer-1.0.0-py2.py3-none-any.whl size=394200 sha256=3d0d6e6256eba6f9253e92e7e1efe851909c552b8807a6afab1c6fe97789420b
#   Stored in directory: /home/model-server/tmp/pip-ephem-wheel-cache-1rjdfewg/wheels/3e/0f/51/2f1df833dd0412c1bc2f5ee56baac195b5be563353d111dca6
# Successfully built featurizer
# Installing collected packages: pyyaml, featurizer
# Successfully installed featurizer-1.0.0 pyyaml-5.4.1
# [2021-06-24 22:13:47 +0000] [36] [INFO] Starting gunicorn 20.0.4
# [2021-06-24 22:13:47 +0000] [36] [INFO] Listening at: unix:/tmp/gunicorn.sock (36)
# [2021-06-24 22:13:47 +0000] [36] [INFO] Using worker: gevent
# [2021-06-24 22:13:47 +0000] [39] [INFO] Booting worker with pid: 39
# [2021-06-24 22:13:47 +0000] [40] [INFO] Booting worker with pid: 40
# [2021-06-24 22:13:47 +0000] [44] [INFO] Booting worker with pid: 44
# [2021-06-24 22:13:47 +0000] [45] [INFO] Booting worker with pid: 45
# 2021-06-24 22:13:49,561 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2021-06-24 22:13:44,764 INFO - sagemaker-containers - nginx config:
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr;
#
# worker_rlimit_nofile 4096;
#
# events {
#   worker_connections 2048;
# }
#
# http {
#   include /etc/nginx/mime.types;
#   default_type application/octet-stream;
#   access_log /dev/stdout combined;
#
#   upstream gunicorn {
#     server unix:/tmp/gunicorn.sock;
#   }
#
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#
#     keepalive_timeout 3;
#
#     location ~ ^/(ping|invocations|execution-parameters) {
#       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#       proxy_set_header Host $http_host;
#       proxy_redirect off;
#       proxy_read_timeout 60s;
#       proxy_pass http://gunicorn;
#     }
#
#     location / {
#       return 404 "{}";
#     }
#
#   }
# }
#
#
# 2021-06-24 22:13:44,938 INFO - sagemaker-containers - Module featurizer does not provide a setup.py.
# Generating setup.py
# 2021-06-24 22:13:44,938 INFO - sagemaker-containers - Generating setup.cfg
# 2021-06-24 22:13:44,938 INFO - sagemaker-containers - Generating MANIFEST.in
# 2021-06-24 22:13:44,939 INFO - sagemaker-containers - Installing module with the following command:
# /miniconda3/bin/python -m pip install . -r requirements.txt
# Processing /opt/ml/code
# Collecting pyyaml==5.4.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
# Building wheels for collected packages: featurizer
#   Building wheel for featurizer (setup.py): started
#   Building wheel for featurizer (setup.py): finished with status 'done'
#   Created wheel for featurizer: filename=featurizer-1.0.0-py2.py3-none-any.whl size=394200 sha256=3d0d6e6256eba6f9253e92e7e1efe851909c552b8807a6afab1c6fe97789420b
#   Stored in directory: /home/model-server/tmp/pip-ephem-wheel-cache-1rjdfewg/wheels/3e/0f/51/2f1df833dd0412c1bc2f5ee56baac195b5be563353d111dca6
# Successfully built featurizer
# Installing collected packages: pyyaml, featurizer
# Successfully installed featurizer-1.0.0 pyyaml-5.4.1
# [2021-06-24 22:13:47 +0000] [36] [INFO] Starting gunicorn 20.0.4
# [2021-06-24 22:13:47 +0000] [36] [INFO] Listening at: unix:/tmp/gunicorn.sock (36)
# [2021-06-24 22:13:47 +0000] [36] [INFO] Using worker: gevent
# [2021-06-24 22:13:47 +0000] [39] [INFO] Booting worker with pid: 39
# [2021-06-24 22:13:47 +0000] [40] [INFO] Booting worker with pid: 40
# [2021-06-24 22:13:47 +0000] [44] [INFO] Booting worker with pid: 44
# [2021-06-24 22:13:47 +0000] [45] [INFO] Booting worker with pid: 45
# 2021-06-24 22:13:49,561 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [24/Jun/2021:22:13:50 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Jun/2021:22:13:50 +0000] "GET /execution-parameters HTTP/1.1" 404 232 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Jun/2021:22:13:50 +0000] "POST /invocations HTTP/1.1" 200 436211 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Jun/2021:22:13:50 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Jun/2021:22:13:50 +0000] "GET /execution-parameters HTTP/1.1" 404 232 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Jun/2021:22:13:50 +0000] "POST /invocations HTTP/1.1" 200 436211 "-" "Go-http-client/1.1"
# 2021-06-24T22:13:50.084:[sagemaker logs]: MaxConcurrentTransforms=1, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# ................................2021-06-24 22:19:31,018 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2021-06-24 22:19:31,018 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2021-06-24 22:19:31,021 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2021-06-24 22:19:31,022 INFO - sagemaker-containers - nginx config:
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr;
#
# worker_rlimit_nofile 4096;
#
# events {
#   worker_connections 2048;
# }
#
# http {
#   include /etc/nginx/mime.types;
#   default_type application/octet-stream;
#   access_log /dev/stdout combined;
#
#   upstream gunicorn {
#     server unix:/tmp/gunicorn.sock;
#   }
#
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#
#     keepalive_timeout 3;
#
#     location ~ ^/(ping|invocations|execution-parameters) {
#       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#       proxy_set_header Host $http_host;
#       proxy_redirect off;
#       proxy_read_timeout 60s;
#       proxy_pass http://gunicorn;
#     }
#
#     location / {
#       return 404 "{}";
#     }
#
#   }
# }
#
#
# 2021-06-24 22:19:31,227 INFO - sagemaker-containers - Module featurizer does not provide a setup.py.
# Generating setup.py
# 2021-06-24 22:19:31,227 INFO - sagemaker-containers - Generating setup.cfg
# 2021-06-24 22:19:31,227 INFO - sagemaker-containers - Generating MANIFEST.in
# 2021-06-24 22:19:31,227 INFO - sagemaker-containers - Installing module with the following command:
# /miniconda3/bin/python -m pip install . -r requirements.txt
# Processing /opt/ml/code
# 2021-06-24 22:19:31,021 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2021-06-24 22:19:31,022 INFO - sagemaker-containers - nginx config:
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr;
#
# worker_rlimit_nofile 4096;
#
# events {
#   worker_connections 2048;
# }
#
# http {
#   include /etc/nginx/mime.types;
#   default_type application/octet-stream;
#   access_log /dev/stdout combined;
#
#   upstream gunicorn {
#     server unix:/tmp/gunicorn.sock;
#   }
#
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#
#     keepalive_timeout 3;
#
#     location ~ ^/(ping|invocations|execution-parameters) {
#       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#       proxy_set_header Host $http_host;
#       proxy_redirect off;
#       proxy_read_timeout 60s;
#       proxy_pass http://gunicorn;
#     }
#
#     location / {
#       return 404 "{}";
#     }
#
#   }
# }
#
#
# 2021-06-24 22:19:31,227 INFO - sagemaker-containers - Module featurizer does not provide a setup.py.
# Generating setup.py
# 2021-06-24 22:19:31,227 INFO - sagemaker-containers - Generating setup.cfg
# 2021-06-24 22:19:31,227 INFO - sagemaker-containers - Generating MANIFEST.in
# 2021-06-24 22:19:31,227 INFO - sagemaker-containers - Installing module with the following command:
# /miniconda3/bin/python -m pip install . -r requirements.txt
# Processing /opt/ml/code
# Collecting pyyaml==5.4.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
# Building wheels for collected packages: featurizer
#   Building wheel for featurizer (setup.py): started
#   Building wheel for featurizer (setup.py): finished with status 'done'
#   Created wheel for featurizer: filename=featurizer-1.0.0-py2.py3-none-any.whl size=394200 sha256=2c0b26155b325a35bfe441d54ea9af3dbefd41e3baa5a2b799afdc705951e39d
#   Stored in directory: /home/model-server/tmp/pip-ephem-wheel-cache-0yg3b6gr/wheels/3e/0f/51/2f1df833dd0412c1bc2f5ee56baac195b5be563353d111dca6
# Successfully built featurizer
# Collecting pyyaml==5.4.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
# Building wheels for collected packages: featurizer
#   Building wheel for featurizer (setup.py): started
#   Building wheel for featurizer (setup.py): finished with status 'done'
#   Created wheel for featurizer: filename=featurizer-1.0.0-py2.py3-none-any.whl size=394200 sha256=2c0b26155b325a35bfe441d54ea9af3dbefd41e3baa5a2b799afdc705951e39d
#   Stored in directory: /home/model-server/tmp/pip-ephem-wheel-cache-0yg3b6gr/wheels/3e/0f/51/2f1df833dd0412c1bc2f5ee56baac195b5be563353d111dca6
# Successfully built featurizer
# Installing collected packages: pyyaml, featurizer
# Successfully installed featurizer-1.0.0 pyyaml-5.4.1
# Installing collected packages: pyyaml, featurizer
# Successfully installed featurizer-1.0.0 pyyaml-5.4.1
# [2021-06-24 22:19:33 +0000] [36] [INFO] Starting gunicorn 20.0.4
# [2021-06-24 22:19:33 +0000] [36] [INFO] Starting gunicorn 20.0.4
# [2021-06-24 22:19:33 +0000] [36] [INFO] Listening at: unix:/tmp/gunicorn.sock (36)
# [2021-06-24 22:19:33 +0000] [36] [INFO] Using worker: gevent
# [2021-06-24 22:19:33 +0000] [39] [INFO] Booting worker with pid: 39
# [2021-06-24 22:19:33 +0000] [40] [INFO] Booting worker with pid: 40
# [2021-06-24 22:19:33 +0000] [44] [INFO] Booting worker with pid: 44
# [2021-06-24 22:19:33 +0000] [45] [INFO] Booting worker with pid: 45
# [2021-06-24 22:19:33 +0000] [36] [INFO] Listening at: unix:/tmp/gunicorn.sock (36)
# [2021-06-24 22:19:33 +0000] [36] [INFO] Using worker: gevent
# [2021-06-24 22:19:33 +0000] [39] [INFO] Booting worker with pid: 39
# [2021-06-24 22:19:33 +0000] [40] [INFO] Booting worker with pid: 40
# [2021-06-24 22:19:33 +0000] [44] [INFO] Booting worker with pid: 44
# [2021-06-24 22:19:33 +0000] [45] [INFO] Booting worker with pid: 45
# 2021-06-24 22:19:35,739 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [24/Jun/2021:22:19:36 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# 2021-06-24 22:19:36,273 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2021-06-24 22:19:35,739 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [24/Jun/2021:22:19:36 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# 2021-06-24 22:19:36,273 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [24/Jun/2021:22:19:36 +0000] "GET /execution-parameters HTTP/1.1" 404 232 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Jun/2021:22:19:36 +0000] "POST /invocations HTTP/1.1" 200 94017 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Jun/2021:22:19:36 +0000] "GET /execution-parameters HTTP/1.1" 404 232 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Jun/2021:22:19:36 +0000] "POST /invocations HTTP/1.1" 200 94017 "-" "Go-http-client/1.1"
# 2021-06-24T22:19:36.783:[sagemaker logs]: MaxConcurrentTransforms=1, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
#
# 2021-06-24 22:19:31,018 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2021-06-24 22:19:31,018 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2021-06-24 22:19:31,021 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2021-06-24 22:19:31,022 INFO - sagemaker-containers - nginx config:
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr;
#
# worker_rlimit_nofile 4096;
#
# events {
#   worker_connections 2048;
# }
#
# http {
#   include /etc/nginx/mime.types;
#   default_type application/octet-stream;
#   access_log /dev/stdout combined;
#
#   upstream gunicorn {
#     server unix:/tmp/gunicorn.sock;
#   }
#
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#
#     keepalive_timeout 3;
#
#     location ~ ^/(ping|invocations|execution-parameters) {
#       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#       proxy_set_header Host $http_host;
#       proxy_redirect off;
#       proxy_read_timeout 60s;
#       proxy_pass http://gunicorn;
#     }
#
#     location / {
#       return 404 "{}";
#     }
#
#   }
# }
#
#
# 2021-06-24 22:19:31,227 INFO - sagemaker-containers - Module featurizer does not provide a setup.py.
# Generating setup.py
# 2021-06-24 22:19:31,227 INFO - sagemaker-containers - Generating setup.cfg
# 2021-06-24 22:19:31,227 INFO - sagemaker-containers - Generating MANIFEST.in
# 2021-06-24 22:19:31,227 INFO - sagemaker-containers - Installing module with the following command:
# /miniconda3/bin/python -m pip install . -r requirements.txt
# Processing /opt/ml/code
# 2021-06-24 22:19:31,021 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2021-06-24 22:19:31,022 INFO - sagemaker-containers - nginx config:
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr;
#
# worker_rlimit_nofile 4096;
#
# events {
#   worker_connections 2048;
# }
#
# http {
#   include /etc/nginx/mime.types;
#   default_type application/octet-stream;
#   access_log /dev/stdout combined;
#
#   upstream gunicorn {
#     server unix:/tmp/gunicorn.sock;
#   }
#
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#
#     keepalive_timeout 3;
#
#     location ~ ^/(ping|invocations|execution-parameters) {
#       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#       proxy_set_header Host $http_host;
#       proxy_redirect off;
#       proxy_read_timeout 60s;
#       proxy_pass http://gunicorn;
#     }
#
#     location / {
#       return 404 "{}";
#     }
#
#   }
# }
#
#
# 2021-06-24 22:19:31,227 INFO - sagemaker-containers - Module featurizer does not provide a setup.py.
# Generating setup.py
# 2021-06-24 22:19:31,227 INFO - sagemaker-containers - Generating setup.cfg
# 2021-06-24 22:19:31,227 INFO - sagemaker-containers - Generating MANIFEST.in
# 2021-06-24 22:19:31,227 INFO - sagemaker-containers - Installing module with the following command:
# /miniconda3/bin/python -m pip install . -r requirements.txt
# Processing /opt/ml/code
# Collecting pyyaml==5.4.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
# Building wheels for collected packages: featurizer
#   Building wheel for featurizer (setup.py): started
#   Building wheel for featurizer (setup.py): finished with status 'done'
#   Created wheel for featurizer: filename=featurizer-1.0.0-py2.py3-none-any.whl size=394200 sha256=2c0b26155b325a35bfe441d54ea9af3dbefd41e3baa5a2b799afdc705951e39d
#   Stored in directory: /home/model-server/tmp/pip-ephem-wheel-cache-0yg3b6gr/wheels/3e/0f/51/2f1df833dd0412c1bc2f5ee56baac195b5be563353d111dca6
# Successfully built featurizer
# Collecting pyyaml==5.4.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
# Building wheels for collected packages: featurizer
#   Building wheel for featurizer (setup.py): started
#   Building wheel for featurizer (setup.py): finished with status 'done'
#   Created wheel for featurizer: filename=featurizer-1.0.0-py2.py3-none-any.whl size=394200 sha256=2c0b26155b325a35bfe441d54ea9af3dbefd41e3baa5a2b799afdc705951e39d
#   Stored in directory: /home/model-server/tmp/pip-ephem-wheel-cache-0yg3b6gr/wheels/3e/0f/51/2f1df833dd0412c1bc2f5ee56baac195b5be563353d111dca6
# Successfully built featurizer
# Installing collected packages: pyyaml, featurizer
# Successfully installed featurizer-1.0.0 pyyaml-5.4.1
# Installing collected packages: pyyaml, featurizer
# Successfully installed featurizer-1.0.0 pyyaml-5.4.1
# [2021-06-24 22:19:33 +0000] [36] [INFO] Starting gunicorn 20.0.4
# [2021-06-24 22:19:33 +0000] [36] [INFO] Starting gunicorn 20.0.4
# [2021-06-24 22:19:33 +0000] [36] [INFO] Listening at: unix:/tmp/gunicorn.sock (36)
# [2021-06-24 22:19:33 +0000] [36] [INFO] Using worker: gevent
# [2021-06-24 22:19:33 +0000] [39] [INFO] Booting worker with pid: 39
# [2021-06-24 22:19:33 +0000] [40] [INFO] Booting worker with pid: 40
# [2021-06-24 22:19:33 +0000] [44] [INFO] Booting worker with pid: 44
# [2021-06-24 22:19:33 +0000] [45] [INFO] Booting worker with pid: 45
# [2021-06-24 22:19:33 +0000] [36] [INFO] Listening at: unix:/tmp/gunicorn.sock (36)
# [2021-06-24 22:19:33 +0000] [36] [INFO] Using worker: gevent
# [2021-06-24 22:19:33 +0000] [39] [INFO] Booting worker with pid: 39
# [2021-06-24 22:19:33 +0000] [40] [INFO] Booting worker with pid: 40
# [2021-06-24 22:19:33 +0000] [44] [INFO] Booting worker with pid: 44
# [2021-06-24 22:19:33 +0000] [45] [INFO] Booting worker with pid: 45
# 2021-06-24 22:19:35,739 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [24/Jun/2021:22:19:36 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# 2021-06-24 22:19:36,273 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2021-06-24 22:19:35,739 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [24/Jun/2021:22:19:36 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# 2021-06-24 22:19:36,273 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [24/Jun/2021:22:19:36 +0000] "GET /execution-parameters HTTP/1.1" 404 232 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Jun/2021:22:19:36 +0000] "POST /invocations HTTP/1.1" 200 94017 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Jun/2021:22:19:36 +0000] "GET /execution-parameters HTTP/1.1" 404 232 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Jun/2021:22:19:36 +0000] "POST /invocations HTTP/1.1" 200 94017 "-" "Go-http-client/1.1"
# 2021-06-24T22:19:36.783:[sagemaker logs]: MaxConcurrentTransforms=1, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD

# %%
# sess.upload_data(
#     path='schema.yml', 
#     bucket=bucket,
#     key_prefix='abalone'
# )
transformed_X_train
# Out:
# 's3://sagemaker-us-east-1-926521026587/sagemaker-scikit-learn-2021-06-24-22-08-40-316'

# %% [markdown]
# # Train linear learner on separate instance

# %%
ll_image = retrieve("linear-learner", region)

# %%
s3_ll_output_key_prefix = "ll_training_output"
s3_ll_output_location = "s3://{}/{}/{}".format(
    bucket, s3_ll_output_key_prefix, "ll_model"
)

# %%
ll_estimator = sagemaker.estimator.Estimator(
    ll_image,
    role,
    instance_count=1,
    instance_type="ml.m4.2xlarge",
    volume_size=20,
    max_run=3600,
    input_mode="File",
    output_path=s3_ll_output_location,
    sagemaker_session=sess,
)

ll_estimator.set_hyperparameters(feature_dim=9, predictor_type="regressor", mini_batch_size=32)

ll_train_data = sagemaker.inputs.TrainingInput(
    transformed_X_train,
    distribution="FullyReplicated",
    content_type="text/csv",
    s3_data_type="S3Prefix",
)

data_channels = {"train": ll_train_data}

# %%
ll_estimator.fit(inputs=data_channels, wait=True, logs=True)
# Out:
# 2021-06-24 22:39:50 Starting - Starting the training job...
# 2021-06-24 22:40:00 Starting - Launching requested ML instancesProfilerReport-1624574390: InProgress
# ........

# %%
timestamp_prefix = strftime("%Y-%m-%d-%H-%M-%S", gmtime())

featurizer_model = featurizer.create_model()
linear_learner_model = ll_estimator.create_model()

model_name = "inference-pipeline-" + timestamp_prefix
sm_model = PipelineModel(
    name=model_name, role=role, models=[scikit_learn_inferencee_model, linear_learner_model]
)
